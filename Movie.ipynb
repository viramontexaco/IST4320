# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()
root.title("Favorite Movie Tracker")
root.geometry("350x300")

tk.Label(root, text="Favorite Movie Tracker", font=("Arial", 14)).pack(pady=10)

tk.Label(root, text="Movie Title").pack()
title_entry = tk.Entry(root)
title_entry.pack()


tk.Label(root, text="Genre").pack()
genre_combo = ttk.Combobox(root, values=["Action", "Comedy", "Drama", "Sci-Fi", "Horror"])
genre_combo.pack()

save_btn = tk.Button(root, text="Save Movie")
save_btn.pack(pady=10)

status_label = tk.Label(root, text="")
status_label.pack()

root.mainloop()

import sqlite3

def save_movie():
    title = title_entry.get()
    year = year_entry.get()
    genre = genre_combo.get()

    conn = sqlite3.connect("movies.db")
    cursor = conn.cursor()

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS movies (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            year TEXT,
            genre TEXT
        )
    """)

    cursor.execute(
        "INSERT INTO movies (title, year, genre) VALUES (?, ?, ?)",
        (title, year, genre)
    )

    conn.commit()
    conn.close()

    status_label.config(text="Movie saved successfully!")
    
save_btn.config(command=save_movie)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[11], line 56
#      52     conn.close()
#      54     status_label.config(text="Movie saved successfully!")
# ---> 56 save_btn.config(command=save_movie)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:1822, in Misc.configure(self, cnf, **kw)
#    1815 def configure(self, cnf=None, **kw):
#    1816     """Configure resources of a widget.
#    1817
#    1818     The values for resources are specified as keyword
#    1819     arguments. To get an overview about
#    1820     the allowed keyword arguments call the method keys.
#    1821     """
# -> 1822     return self._configure('configure', cnf, kw)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:1812, in Misc._configure(self, cmd, cnf, kw)
#    1810 if isinstance(cnf, str):
#    1811     return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# ...
